# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $f(x) = x^2 + x + 1$

# %%
def f(x):
    return x**2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim([-3,3])
plt.ylim(0,8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives

# %%
def df(x):
    return 2*x + 1

# %%
# Plot function and derivative side by side

plt.figure(figsize=[15,5]) # Total size of the entire figure. In this case, both charts side by side.

# First chart: Cost Function
plt.subplot(1, 2, 1) # plt.subplot(rows, columns, index)

plt.xlim([-3,3])
plt.ylim(0,8)

plt.title('Cost Function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# Second Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the Cost Function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()

plt.xlim([-2, 3])
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Python Loops & Gradient Descent

# %%
# Python For Loop
for n in range(5):
    print('Hello World', n)
print('End of Loop')
# Out:
# Hello World 0
# Hello World 1
# Hello World 2
# Hello World 3
# Hello World 4
# End of Loop

# %%
# Python While Loop
counter = 0
while counter < 7:
    print('Counting ...', counter)
    counter += 1
print('End of loop.')
# Out:
# Counting ... 0
# Counting ... 1
# Counting ... 2
# Counting ... 3
# Counting ... 4
# Counting ... 5
# Counting ... 6
# End of loop.

# %%
# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.0001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient
    
    step_size = abs(new_x - previous_x)
    # print(step_size)
    
    x_list.append(new_x)
    slope_list.append(df(new_x))
    
    if step_size < precision:
        print('Loop ran this many times:', n)
        break
    
print('Local minimum occurs at:', new_x)
print('Slope or df(x) value this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 40
# Local minimum occurs at: -0.49962781616118024
# Slope or df(x) value this point is: 0.0007443676776395236
# f(x) value or cost at this point is: 0.7500001385208099

# %%
# Superimpost the gradient descent calculation on plot

plt.figure(figsize=[20,5]) # Total size of the entire figure. In this case, both charts side by side.

# First chart: Cost Function
plt.subplot(1, 3, 1) # plt.subplot(rows, columns, index)

plt.xlim([-3,3])
plt.ylim(0,8)

plt.title('Cost Function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6) # s equals the size of the scatter plot points

# Second Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the Cost Function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()

plt.xlim([-2, 3])
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# Third Chart: Gradient Descent (close up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()

plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()
